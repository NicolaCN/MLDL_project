# %% [markdown]
# <a href="https://colab.research.google.com/github/NicolaCN/MLDL_project/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import sys
import os
sys.path.append(os.path.abspath("/content/drive/MyDrive/Research_Project"))

# %%
# !pip install torch==2.0.0
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 619.9/619.9 MB 2.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.0/21.0 MB 55.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 849.3/849.3 kB 57.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.8/11.8 MB 79.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 557.1/557.1 MB 3.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 317.1/317.1 MB 2.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 168.4/168.4 MB 6.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.6/54.6 MB 15.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 102.6/102.6 MB 8.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 173.2/173.2 MB 7.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 177.1/177.1 MB 6.5 MB/s eta 0:00:00
# ...

# %%
# !python /content/drive/MyDrive/Research_Project/code/train.py /content/drive/MyDrive/Research_Project/data/video/All_Subs_Diff_Modules_nofilter_withoutAUc.csv
# Out:
# 2.0.0+cu117
# Using cuda
# Number of features: 100
# Generating train/val/test split...
# Generating sequences...
# Number of training examples: 1371
# Number of validation examples: 117
# Number of test examples: 602
# Subject: 0/0  Epoch:   0  Loss: 0.899321/0.555127  Validation accuracy: 0.60
#     Max validation for this run. Current max: 0.5982906222343445
#     Saving model to checkpoint.ckpt
# Subject: 0/0  Epoch:   1  Loss: 0.452529/0.434894  Validation accuracy: 0.79
#     Max validation for this run. Current max: 0.7948718070983887
#     Saving model to checkpoint.ckpt
# Subject: 0/0  Epoch:   2  Loss: 0.357176/0.146686  Validation accuracy: 0.71
# Subject: 0/0  Epoch:   3  Loss: 0.377019/0.216824  Validation accuracy: 0.74
# Subject: 0/0  Epoch:   4  Loss: 0.296429/0.104998  Validation accuracy: 0.72
# Subject: 0/0  Epoch:   5  Loss: 0.266905/0.221949  Validation accuracy: 0.80
#     Max validation for this run. Current max: 0.8034188151359558
# ...

# %% [markdown]
# # Nuova sezione
